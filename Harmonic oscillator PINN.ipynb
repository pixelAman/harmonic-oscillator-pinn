# %% [markdown]
# # 1D harmonic oscillator physics-informed neural network (PINN)
#
# This notebook contains the code to reproduce the plots presented in my blog post ["So, what is a physics-informed neural network?"](https://benmoseley.blog/my-research/so-what-is-a-physics-informed-neural-network/).
#
# Please read the post for more details!
#
# ## Problem overview
#
# The example problem we solve here is the 1D damped harmonic oscillator:
# $$
# m \dfrac{d^2 x}{d t^2} + \mu \dfrac{d x}{d t} + kx = 0~,
# $$
# with the initial conditions
# $$
# x(0) = 1~~,~~\dfrac{d x}{d t} = 0~.
# $$
# We will focus on solving the problem for the under-damped state, i.e. when
# $$
# \delta < \omega_0~,~~~~~\mathrm{with}~~\delta = \dfrac{\mu}{2m}~,~\omega_0 = \sqrt{\dfrac{k}{m}}~.
# $$
# This has the following exact solution:
# $$
# x(t) = e^{-\delta t}(2 A \cos(\phi + \omega t))~,~~~~~\mathrm{with}~~\omega=\sqrt{\omega_0^2 - \delta^2}~.
# $$
#
# This problem was inspired by the following blog post: https://beltoforion.de/en/harmonic_oscillator/.
#
# ## Workflow overview
#
# >First we will train a standard neural network to interpolate a small part of the solution, using some observed training points from the solution.
#
# >Next, we will train a PINN to extrapolate the full solution outside of these training points by penalising the underlying differential equation in its loss function.
#
#
# ## Environment set up
#
# We train the PINN using PyTorch, using the following environment set up:
# ```bash
#
# conda create -n pinn python=3
# conda activate pinn
# conda install jupyter numpy matplotlib
# conda install pytorch torchvision torchaudio -c pytorch
# ```

# %% [markdown]
# #  Carbon Emission
# ## For estimation of its carbon footprint:
# ### We  Import codecarbon

# %%
import os

# Create the 'plots' folder if it doesn't exist
if not os.path.exists('plots'):
    os.makedirs('plots')
from codecarbon import EmissionsTracker

from PIL import Image

import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

tracker = EmissionsTracker(project_name = "Harmonic oscillator PINN",)
#stared tracking here
tracker.start()
# Out:
# [codecarbon WARNING @ 01:49:40] Multiple instances of codecarbon are allowed to run at the same time.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 16
#      13 import torch.nn as nn
#      14 import matplotlib.pyplot as plt
# ---> 16 tracker = EmissionsTracker(project_name = "Harmonic oscillator PINN",)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\codecarbon\emissions_tracker.py:365, in BaseEmissionsTracker.__init__(self, project_name, measure_power_secs, api_call_interval, api_endpoint, api_key, output_dir, output_file, save_to_file, save_to_api, save_to_logger, logging_logger, save_to_prometheus, save_to_logfire, prometheus_url, output_handlers, gpu_ids, emissions_endpoint, experiment_id, experiment_name, electricitymaps_api_token, co2_signal_api_token, tracking_mode, log_level, on_csv_write, logger_preamble, force_cpu_power, force_ram_power, pue, wue, force_mode_cpu_load, allow_multiple_runs, rapl_include_dram, rapl_prefer_psys)
#     363 self._conf["python_version"] = platform.python_version()
#     364 self._conf["cpu_count"] = count_cpus()
# --> 365 self._conf["cpu_physical_count"] = count_physical_cpus()
#     366 self._geo = None
#     367 self._task_start_measurement_values = {}
#
# File ~\AppData\Roaming\Python\Python311\site-packages\codecarbon\core\util.py:106, in count_physical_cpus()
#     103 import subprocess
#     105 if platform.system() == "Windows":
# --> 106     return _windows_get_physical_sockets()
#     107 else:
#     108     try:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\codecarbon\core\util.py:131, in _windows_get_physical_sockets()
#     123 try:
#     124     # use PowerShell to count number of objects of class Win32_Processor
#     125     cmd = [
#     126         "powershell",
#     127         "-NoProfile",
#     128         "-Command",
#     129         "(Get-CimInstance -ClassName Win32_Processor).Count",
#     130     ]
# --> 131     result = subprocess.run(
#     132         cmd, capture_output=True, text=True, timeout=10, check=True
#     133     )
#     135     output = result.stdout.strip() or "1"
#     136     logger.debug(f"Detected {output} physical sockets on Windows.")
#
# File c:\Program Files\Python311\Lib\subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File c:\Program Files\Python311\Lib\subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File c:\Program Files\Python311\Lib\subprocess.py:1628, in Popen._communicate(self, input, endtime, orig_timeout)
#    1624 # Wait for the reader threads, or time out.  If we time out, the
#    1625 # threads remain reading and the fds left open in case the user
#    1626 # calls communicate again.
#    1627 if self.stdout is not None:
# -> 1628     self.stdout_thread.join(self._remaining_time(endtime))
#    1629     if self.stdout_thread.is_alive():
#    1630         raise TimeoutExpired(self.args, orig_timeout)
#
# File c:\Program Files\Python311\Lib\threading.py:1123, in Thread.join(self, timeout)
#    1119     self._wait_for_tstate_lock()
#    1120 else:
#    1121     # the behavior of a negative timeout isn't documented, but
#    1122     # historically .join(timeout=x) for x<0 has acted as if timeout=0
# -> 1123     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File c:\Program Files\Python311\Lib\threading.py:1139, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1136     return
#    1138 try:
# -> 1139     if lock.acquire(block, timeout):
#    1140         lock.release()
#    1141         self._stop()
#
# KeyboardInterrupt:

# %%
def save_gif_PIL(outfile, files, fps=5, loop=0):
    "Helper function for saving GIFs"
    imgs = [Image.open(file) for file in files]
    imgs[0].save(fp=outfile, format='GIF', append_images=imgs[1:], save_all=True, duration=int(1000/fps), loop=loop)
    
def oscillator(d, w0, x):
    """Defines the analytical solution to the 1D underdamped harmonic oscillator problem. 
    Equations taken from: https://beltoforion.de/en/harmonic_oscillator/"""
    assert d < w0
    w = np.sqrt(w0**2-d**2)
    phi = np.arctan(-d/w)
    A = 1/(2*np.cos(phi))
    cos = torch.cos(phi+w*x)
    sin = torch.sin(phi+w*x)
    exp = torch.exp(-d*x)
    y  = exp*2*A*cos
    return y

class FCN(nn.Module):
    "Defines a connected network"
    
    def __init__(self, N_INPUT, N_OUTPUT, N_HIDDEN, N_LAYERS):
        super().__init__()
        activation = nn.Tanh
        self.fcs = nn.Sequential(*[
                        nn.Linear(N_INPUT, N_HIDDEN),
                        activation()])
        self.fch = nn.Sequential(*[
                        nn.Sequential(*[
                            nn.Linear(N_HIDDEN, N_HIDDEN),
                            activation()]) for _ in range(N_LAYERS-1)])
        self.fce = nn.Linear(N_HIDDEN, N_OUTPUT)
        
    def forward(self, x):
        x = self.fcs(x)
        x = self.fch(x)
        x = self.fce(x)
        return x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 tracker.start()
#       2 def save_gif_PIL(outfile, files, fps=5, loop=0):
#       3     "Helper function for saving GIFs"
#
# NameError: name 'tracker' is not defined

# %% [markdown]
# ## Generate training data
#
# > First, we generate some training data from a small part of the true analytical solution.
#
# For this problem, we use $\delta=2$, $\omega_0=20$, and try to learn the solution over the domain $x\in [0,1]$.

# %%
d, w0 = 2, 20

# get the analytical solution over the full domain
x = torch.linspace(0,1,500).view(-1,1)
y = oscillator(d, w0, x).view(-1,1)
print(x.shape, y.shape)

# slice out a small number of points from the LHS of the domain
x_data = x[0:200:20]
y_data = y[0:200:20]
print(x_data.shape, y_data.shape)

plt.figure()
plt.plot(x, y, label="Exact solution")
plt.scatter(x_data, y_data, color="tab:orange", label="Training data")
plt.legend()
plt.show()
# Out:
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([10, 1]) torch.Size([10, 1])

# %% [markdown]
# ## Normal neural network
#
# > Next, we train a standard neural network (fully connected network) to fit these training points.
#
# >We find that the network is able to fit the solution very closely in the vicinity of the training points, but does not learn an accurate solution outside of them.

# %%
def plot_result(x,y,x_data,y_data,yh,xp=None):
    "Pretty plot training results"
    plt.figure(figsize=(8,4))
    plt.plot(x,y, color="grey", linewidth=2, alpha=0.8, label="Exact solution")
    plt.plot(x,yh, color="tab:blue", linewidth=4, alpha=0.8, label="Neural network prediction")
    plt.scatter(x_data, y_data, s=60, color="tab:orange", alpha=0.4, label='Training data')
    if xp is not None:
        plt.scatter(xp, -0*torch.ones_like(xp), s=60, color="tab:green", alpha=0.4, 
                    label='Physics loss training locations')
    l = plt.legend(loc=(1.01,0.34), frameon=False, fontsize="large")
    plt.setp(l.get_texts(), color="k")
    plt.xlim(-0.05, 1.05)
    plt.ylim(-1.1, 1.1)
    plt.text(1.065,0.7,"Training step: %i"%(i+1),fontsize="xx-large",color="k")
    plt.axis("off")
    
    
# train standard neural network to fit training data
torch.manual_seed(123)
model = FCN(1,1,32,3)
optimizer = torch.optim.Adam(model.parameters(),lr=1e-3)
files = []
for i in range(1000):
    optimizer.zero_grad()
    yh = model(x_data)
    loss = torch.mean((yh-y_data)**2)# use mean squared error
    loss.backward()
    optimizer.step()
    
    
    # plot the result as training progresses
    if (i+1) % 10 == 0: 
        
        yh = model(x).detach()
        
        plot_result(x,y,x_data,y_data,yh)
        
        file = "plots/nn_%.8i.png"%(i+1)
        plt.savefig(file, bbox_inches='tight', pad_inches=0.1, dpi=100, facecolor="white")
        files.append(file)
    
        if (i+1) % 500 == 0: plt.show()
        else: plt.close("all")
            
save_gif_PIL("nn.gif", files, fps=20, loop=0)
# Out:
# [codecarbon INFO @ 16:34:09] Energy consumed for RAM : 0.000044 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:34:10] Delta energy consumed for CPU with cpu_load : 0.000021 kWh, power : 4.6245011730000005 W
# [codecarbon INFO @ 16:34:10] Energy consumed for All CPU : 0.000021 kWh
# [codecarbon INFO @ 16:34:10] 0.000065 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 16:34:24] Energy consumed for RAM : 0.000085 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:34:25] Delta energy consumed for CPU with cpu_load : 0.000019 kWh, power : 4.78247012565 W
# [codecarbon INFO @ 16:34:25] Energy consumed for All CPU : 0.000040 kWh
# [codecarbon INFO @ 16:34:25] 0.000124 kWh of electricity and 0.000000 L of water were used since the beginning.

# %% [markdown]
# ## PINN
#
# > Finally, we add the underlying differential equation ("physics loss") to the loss function.
#
# The physics loss aims to ensure that the learned solution is consistent with the underlying differential equation. This is done by penalising the residual of the differential equation over a set of locations sampled from the domain.
#
# Here we evaluate the physics loss at 30 points uniformly spaced over the problem domain $([0,1])$. We can calculate the derivatives of the network solution with respect to its input variable at these points using `pytorch`'s autodifferentiation features, and can then easily compute the residual of the differential equation using these quantities.

# %%
x_physics = torch.linspace(0,1,30).view(-1,1).requires_grad_(True)# sample locations over the problem domain
mu, k = 2*d, w0**2

torch.manual_seed(123)
model = FCN(1,1,32,3)
optimizer = torch.optim.Adam(model.parameters(),lr=1e-4)
files = []
for i in range(20000):
    optimizer.zero_grad()
    
    # compute the "data loss"
    yh = model(x_data)
    loss1 = torch.mean((yh-y_data)**2)# use mean squared error
    
    # compute the "physics loss"
    yhp = model(x_physics)
    dx  = torch.autograd.grad(yhp, x_physics, torch.ones_like(yhp), create_graph=True)[0]# computes dy/dx
    dx2 = torch.autograd.grad(dx,  x_physics, torch.ones_like(dx),  create_graph=True)[0]# computes d^2y/dx^2
    physics = dx2 + mu*dx + k*yhp# computes the residual of the 1D harmonic oscillator differential equation
    loss2 = (1e-4)*torch.mean(physics**2)
    
    # backpropagate joint loss
    loss = loss1 + loss2# add two loss terms together
    loss.backward()
    optimizer.step()
    
    
    # plot the result as training progresses
    if (i+1) % 150 == 0: 
        
        yh = model(x).detach()
        xp = x_physics.detach()
        
        plot_result(x,y,x_data,y_data,yh,xp)
        
        file = "plots/pinn_%.8i.png"%(i+1)
        plt.savefig(file, bbox_inches='tight', pad_inches=0.1, dpi=100, facecolor="white")
        files.append(file)
        
        if (i+1) % 6000 == 0: plt.show()
        else: plt.close("all")
            
save_gif_PIL("pinn.gif", files, fps=20, loop=0)
# Out:
# [codecarbon INFO @ 16:34:39] Energy consumed for RAM : 0.000125 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:34:40] Delta energy consumed for CPU with cpu_load : 0.000016 kWh, power : 3.8756005135125 W
# [codecarbon INFO @ 16:34:40] Energy consumed for All CPU : 0.000055 kWh
# [codecarbon INFO @ 16:34:40] 0.000180 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 16:34:54] Energy consumed for RAM : 0.000165 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:34:55] Delta energy consumed for CPU with cpu_load : 0.000012 kWh, power : 2.9221286425124995 W
# [codecarbon INFO @ 16:34:55] Energy consumed for All CPU : 0.000067 kWh
# [codecarbon INFO @ 16:34:55] 0.000232 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 16:35:09] Energy consumed for RAM : 0.000205 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:35:10] Delta energy consumed for CPU with cpu_load : 0.000011 kWh, power : 2.6568132498375 W
# [codecarbon INFO @ 16:35:10] Energy consumed for All CPU : 0.000078 kWh
# [codecarbon INFO @ 16:35:10] 0.000283 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 16:35:24] Energy consumed for RAM : 0.000245 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:35:25] Delta energy consumed for CPU with cpu_load : 0.000010 kWh, power : 2.56833822624 W
# [codecarbon INFO @ 16:35:25] Energy consumed for All CPU : 0.000088 kWh
# [codecarbon INFO @ 16:35:25] 0.000334 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 16:35:39] Energy consumed for RAM : 0.000286 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:35:40] Delta energy consumed for CPU with cpu_load : 0.000008 kWh, power : 1.9755760065000003 W
# [codecarbon INFO @ 16:35:40] Energy consumed for All CPU : 0.000096 kWh
# [codecarbon INFO @ 16:35:40] 0.000382 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 16:35:54] Energy consumed for RAM : 0.000326 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:35:55] Delta energy consumed for CPU with cpu_load : 0.000009 kWh, power : 2.166532473075 W
# [codecarbon INFO @ 16:35:55] Energy consumed for All CPU : 0.000105 kWh
# [codecarbon INFO @ 16:35:55] 0.000431 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 16:35:55] 0.002526 g.CO2eq/s mean an estimation of 79.67308810929795 kg.CO2eq/year
# [codecarbon INFO @ 16:36:09] Energy consumed for RAM : 0.000366 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:36:10] Delta energy consumed for CPU with cpu_load : 0.000011 kWh, power : 2.6952724051285712 W
# [codecarbon INFO @ 16:36:10] Energy consumed for All CPU : 0.000116 kWh
# [codecarbon INFO @ 16:36:10] 0.000482 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 16:36:24] Energy consumed for RAM : 0.000406 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:36:25] Delta energy consumed for CPU with cpu_load : 0.000011 kWh, power : 2.6404956535200004 W
# [codecarbon INFO @ 16:36:25] Energy consumed for All CPU : 0.000126 kWh
# [codecarbon INFO @ 16:36:25] 0.000533 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 16:36:39] Energy consumed for RAM : 0.000446 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:36:40] Delta energy consumed for CPU with cpu_load : 0.000010 kWh, power : 2.5055855491875 W
# [codecarbon INFO @ 16:36:40] Energy consumed for All CPU : 0.000136 kWh
# [codecarbon INFO @ 16:36:40] 0.000583 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 16:36:54] Energy consumed for RAM : 0.000487 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:36:55] Delta energy consumed for CPU with cpu_load : 0.000009 kWh, power : 2.318786476125 W
# [codecarbon INFO @ 16:36:55] Energy consumed for All CPU : 0.000146 kWh
# [codecarbon INFO @ 16:36:55] 0.000633 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 16:37:09] Energy consumed for RAM : 0.000527 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:37:10] Delta energy consumed for CPU with cpu_load : 0.000010 kWh, power : 2.4900054300375 W
# [codecarbon INFO @ 16:37:10] Energy consumed for All CPU : 0.000156 kWh
# [codecarbon INFO @ 16:37:10] 0.000683 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 16:37:24] Energy consumed for RAM : 0.000567 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:37:25] Delta energy consumed for CPU with cpu_load : 0.000008 kWh, power : 2.0478192976500003 W
# [codecarbon INFO @ 16:37:25] Energy consumed for All CPU : 0.000164 kWh
# [codecarbon INFO @ 16:37:25] 0.000731 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 16:37:39] Energy consumed for RAM : 0.000608 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:37:40] Delta energy consumed for CPU with cpu_load : 0.000009 kWh, power : 2.1640394611500002 W
# [codecarbon INFO @ 16:37:40] Energy consumed for All CPU : 0.000173 kWh
# [codecarbon INFO @ 16:37:40] 0.000780 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 16:37:54] Energy consumed for RAM : 0.000648 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:37:55] Delta energy consumed for CPU with cpu_load : 0.000011 kWh, power : 2.7335926338000003 W
# [codecarbon INFO @ 16:37:55] Energy consumed for All CPU : 0.000184 kWh
# [codecarbon INFO @ 16:37:55] 0.000832 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 16:37:55] 0.002382 g.CO2eq/s mean an estimation of 75.10780158913522 kg.CO2eq/year
# [codecarbon INFO @ 16:38:09] Energy consumed for RAM : 0.000688 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:38:10] Delta energy consumed for CPU with cpu_load : 0.000010 kWh, power : 2.5536279775875004 W
# [codecarbon INFO @ 16:38:10] Energy consumed for All CPU : 0.000194 kWh
# [codecarbon INFO @ 16:38:10] 0.000882 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 16:38:24] Energy consumed for RAM : 0.000728 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:38:25] Delta energy consumed for CPU with cpu_load : 0.000009 kWh, power : 2.1825915820125004 W
# [codecarbon INFO @ 16:38:25] Energy consumed for All CPU : 0.000203 kWh
# [codecarbon INFO @ 16:38:25] 0.000931 kWh of electricity and 0.000000 L of water were used since the beginning.
# [codecarbon INFO @ 16:38:39] Energy consumed for RAM : 0.000768 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:38:40] Delta energy consumed for CPU with cpu_load : 0.000009 kWh, power : 2.2206196736250003 W
# [codecarbon INFO @ 16:38:40] Energy consumed for All CPU : 0.000212 kWh
# [codecarbon INFO @ 16:38:40] 0.000980 kWh of electricity and 0.000000 L of water were used since the beginning.

# %%
emissions_data = tracker.stop()
print(f"Training complete. Total emissions: {emissions_data} kg CO2")
# Out:
# [codecarbon INFO @ 16:38:47] Energy consumed for RAM : 0.000789 kWh. RAM Power : 10.0 W
# [codecarbon INFO @ 16:38:48] Delta energy consumed for CPU with cpu_load : 0.000005 kWh, power : 2.3238096336 W
# [codecarbon INFO @ 16:38:48] Energy consumed for All CPU : 0.000217 kWh
# [codecarbon INFO @ 16:38:48] 0.001005 kWh of electricity and 0.000000 L of water were used since the beginning.
# Training complete. Total emissions: 0.000717278345329484 kg CO2
